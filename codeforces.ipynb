# %% [markdown]
# ![image.png](attachment:7aafe85c-1ba4-4cb8-8faa-56b52f16e4a3.png)

# %%
def emit(w):
    if len(w) =< 10:
        print(w)
    else:
        print(w[0] + str(len(w)-2) + w[-1])

import sys
data = sys.stdin.read().splitlines()
n = int(data[0])
for i in range(1, n+1):
    emit(data[i].strip())
